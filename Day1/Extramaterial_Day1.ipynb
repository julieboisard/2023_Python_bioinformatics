# %% [markdown]
# # **Extra material**

# %% [markdown]
# ## Variables
#
# A variable is the same as in math - a letter or phrase that encodes for something. It must:
# - Start with a letter
# - contain NO spaces
# - cannot equal one of the 'reserved words'.

# %% [markdown]
# Forbidden variables names
# https://realpython.com/python-variables/#object-references
#
#
# ![image.png](attachment:114e83fd-46c1-40ef-874c-67e0ba424620.png)

# %%
# 'apple' is a variable
apple = "fruit"

# %%
# 'x' is a variable
x = "1"

# %% [markdown]
# # Data Types - Strings
#
# Strings are indicated using quotation marks. You can put nearly any character in string as long as it is within the quotation marks.
#
# In the following boxes, lets define some strings. Here's an example:
#
#     myString = "Some text"

# %%
# Make a variable called 'myFavouriteMovie' that stores the string of your favourite Movie (delete ???)
myFavouriteMovie = ???

# %%
# Make a variable called 'starring' that stores a string of an actor in that movie

# %% [markdown]
# Make a new variable called 'movieFact' that will combine your two variables to say "My favourite movie is X and it stars Y."
# To ADD strings together, you must use the `+`. Together:

# %%
# "My favourite movie is X and it stars Y."
movieFact = ???

# %% [markdown]
# ## Data Types - Integers
#
# Integers are whole numbers. Any operation that would result in a non-whole number (that is, with a decimal) will not return a decimal. Here is an example of an integer:
#
#     myInteger = 1

# %%
# Make a variable 'movieYear' that stores the year your favourite movie came out

# %%
# Make a  variable 'currentYear' that stores this year
currentYear = 2021

# %% [markdown]
# To perform simple arithmetic with integers, you can use normal operands. Let's see how many years it has been since your favourite movie came out.

# %%
# Make a variable called 'yearsAgo' that substracts the movieYear from currentYear

# %%
yearsAgo =

# %% [markdown]
# Combine all the variables we have created and print the following:
# "My favourite movie is X starring Y. X came out ### years ago in the year Z "
#
# Note! If it helps, you can redefine the variables here in the code block to see it all together in one place.

# %%
# My favourite movie is X starring Y. X came out ### years ago in the year Z

# %% [markdown]
# ## Editing strings WITH variables
#
# What if you have a variable you want to put IN your string? We'll go over this in class.
#
#        %s # strings
#        %i # integers

# %%
# To add a string 'add_me' to a variable: 

add_me = "is great!"
    
#without the modulus:
myNewString = "myString " + add_me 
    
# with the modulus:
myNewString = "myString %s"  % (add_me)

# %%
# My favourite movie is X starring Y. X came out ### years ago in the year Z 

# Try to write your movie string as before using %s formatting: 

# Stuck? Here's a hint:
myFavouriteMovie = "Forrest Gump"
movieFact = "My favourite movie is %s" % (myFavouriteMovie)
print(movieFact)
# Out:
# My favourite movie is Forrest Gump

# %% [markdown]
# # Examples with Strings and integers

# %%
'Hello World!'          # "" and '' can be used interchangeably

# %%
s = 'Hello\tWorld'                                      # Adds a tab between the words
s                                                       # Notice that s only shows the content

# %% [markdown]
# Notice how just calling the variable s is different than print?

# %%
print(s)                                                # While print() renders the content of s

# %%
s = 'First line.\nSecond line.'                         # \n adds a newline
s                                                       # Without print(), \n is included in the output

# %%
print(s)                                                # With print(), \n produces a new line

# %%
# You can also perform operations on the string
# Here, you will produce 3 x money + must be funny
'Money, ' *3 + 'must be funny'

# %%
# Adding in place:
a = 1
a+= 2

# Note: this is the same as:
a = 1
a = a + 2

#Subtracting in place:
a=1 
a -= 1

# %%
# Adding in place with strings - more like appending
string = "abc"
string += "def"

# You cannot subtract from strings
# NEW: but you can 'replace'
print(string)
string.replace("bcd","")

# %%
string.replace("a","elephant")

# %%
print(string) # notice how it does not effect the original string?

# %% [markdown]
# To replace in the orginal string, we have to overwrite the variable string like this:

# %%
string=string.replace("a","elephant")
print(string)

# %%
# Challenge! With parentheses, you *can* bypass the silly indentation rules of python.
# You can concatenate several strings together

# Only in parentheses/brackets/curlybrackets
# Must end each line with a + (for concatenation), ',' for listing options

text = ('Put several strings within parentheses ' +  
        'to have them joined together, ' +
        'with the use of ' +
        'concatenation')
text

# %% [markdown]
# ## Markdown
# Practice making code blocks with nice markdown text.
# - Convert the box below to markdown
#   - Click in the box
#   - Select the dropdown menu located after the 'fast forward' logo (should stay 'Code')
#   - Select Markdown
# - Write a description about some code you will write in the next block - try using some formating!
#   - **bold**
#   - *italics*
#   - ***both!***
#   - Challenge: `code syntax`

# %%
# Convert this to markdown and delete this line! Detail your code in the next block

# %%
# Write some code here and detail it above.

# %% [markdown]
# ## Operations
#
# Quick reference (hint, double click on this Markdown block to see how to write tables!):
#
# |Operator|Description|Example|
# |:---:|:---|:---|
# |+|adds two operands|x + y|
# |-|subtracts two operands| x - y |
# |\*|multiplies two operands|x \* y|
# |/|divides two operands | x / y|
# |%|'Modulus', returns the remainer of a divions| x % y|
# |\*\*|Exponential, raised to the power of the following number| x \*\* y|

# %% [markdown]
# ## Lists
#
# **Lists**(also called 'arrays' or 'vectors' in other languages) are a collection of ordered items. Lists are represented with square parentheses separated by commas.
#
#         myList = [1,2,3,4]

# %%
this_is_a_list_of_integers = [1,2,3,4]
this_is_a_list_of_strings = ["a","c","b"]

# %% [markdown]
# Lists are **ORDERED** which means you can gain access to items in the list based on their position.  Rembmer the 0-index!

# %%
myList = [1,2,3,4]

# %%
# first item in the list
myList[0]

# %%
# last item in the list
myList[-1]

# %%
# second last item in the list
myList[-2]

# %%
# provide the list starting with the 2nd item (index 1)
myList[1:]

# %%
# provide the last two items in the list
myList[-2:]

# %%
# provide item 2 and item 3 in the list
myList[1:3]

# %% [markdown]
# You can add an item to a list using `.append()` or remove items from a list using `.pop()` or `del` or `.remove()`

# %%
myList = [1,2,3,4]
myList.append("apple")
print(myList)

# %%
myList.pop(1) # 'pops' out the 2nd item in myList
print(myList)

# %%
del myList[1] # deletes the 2nd item in the new myList
print(myList)

# %%
myList.remove("apple") # removes the item called 'apple'
print(myList)

# %% [markdown]
# ## Exercises with Lists

# %%
squares = [1, 4, 9, 16, 25]

# %% [markdown]
# **Add 36 to the list squares**
# - Use the append() method to add items to the end of a list. The `.append()` method adds an item to the list in question, without having to re-assign the list to a new variable.

# %%
# Add 36 to the list square

# %% [markdown]
# **Remove 36 from the list**
#
# - pop() without any input will remove the last item in a list. This is not advisable
# - LIST.remove(36) will remove 36 from the list, but only the first instance
# - del LIST[5] will delete the item with index position 5.

# %%
# Remove 36

# %% [markdown]
# **Reverse the order of the list**
#
# - LIST[::-1] -- will only DISPLAY (not change) the reverse order.
# - LIST.reverse() -- ONLY FOR LISTS which is a method that only works on lists. Reverses it in place. Will change the LIST

# %%
# Reverse list

# %% [markdown]
# **Sum values of list**
#
# I noticed a lot of you trying to use 'sum' to make summations of values. Let's try an example in practice. 'sum' is a funtion you can apply to LISTS OF INTEGERS.

# %%
# sum the list 'squares'
sum(squares)

# %% [markdown]
# **Find maximum/minimum value of list**
#
# Just like sum() you can find the minimum (min) or maximum (max) of a LIST OF INTEGERS/FLOATS or the length of the list with len.

# %%
min(squares)
len(squares)

# %% [markdown]
# **Print "This list has the length X and a maximum value Y"**

# %%
# Here's some help. Fill in the ???:

maximum_value = ???
length = ???
print("This list has the length " +
     ??? +
     " and a maximum value " +
     ??? )

# %% [markdown]
# ### Dictionaries
#
# Dictionaries are incredibly powerful tools for storing information. A dictionary is a list of keys (=entries) and values (=attributes) you would like to store with each key separated with a ':'.  They are stored in {}.

# %%
myDictionary = {"a":1,"b":2,"c":3}

# You can access the value of key 'b' using the following syntax.  
print(myDictionary["b"])

# %%
# or like this:
myDictionary.get("b")

# %%
# You can add elements to a dictionary
myDictionary["d"] = 4
print(myDictionary)

# %%
# Add/subtract elements of a keys
myDictionary["d"] += 5
print(myDictionary)

# %%
# Remove keys from a dictionary 
del myDictionary["d"] 
print(myDictionary)

# %%
# Remove keys from a dictionary 
myDictionary.pop("a")
print(myDictionary)

# %% [markdown]
# ## More exercises
#
# - [W3schools Lists](https://www.w3schools.com/python/exercise.asp?filename=exercise_lists1)
# - [W3schools Dictionaries](https://www.w3schools.com/python/exercise.asp?filename=exercise_dictionaries1)

# %% [markdown]
# ## If, else, elif
#
# These conditional operations return True or False.
#
# - Equals: a == b
# - Not Equals: a != b
# - Less than: a < b
# - Less than or equal to: a <= b
# - Greater than: a > b
# - Greater than or equal to: a >= b

# %%
x=1
if x == 1: # If this statement is TRUE, go into the IF statement
    # MUST INDENT
    print("It's a 1!")

# %%
# if commands can exist alone or with 'else'
# else MUST be in the same indentation level as If

if x == 1: 
    print("It's a 1!")  
else: 
    print("It's not a 1...")

# %% [markdown]
# There is also `elif` (else if) which can help you define additional conditional statements.

# %%
x=1.5
if x<1:
    # if x is less than one, print the following
    print("less than 1")
elif x < 1.5:
    # else, if x is less than 1.5, print the following
    print("less than 1.5")
else:
    # if x does not satisfy the conditions above, print the following
    print("greater than or equal to 1.5")

# %% [markdown]
# You can combine conditional statements like this:

# %%
x = 1.5
b = "potato"
if x > 1 and b == "potato":
    print("let's make french fries!")

# %%
x = 1.5
b = "potato"
if x > 1 or b == "turnip":
    print("let's make french fries!")
    
# python will see the 'or' as it's reading x > 1. 
# since there is an 'or' it doesn't care if b == "turnip" is true or not.

# %%
x = 1.5
b = "potato"

if x > 1 and b == "turnip":
    print("let's make french fries!")
else:
    print("no french fries :(")

# %% [markdown]
# `If/else` statements can also be applied to strings, lists and dictionaries using `in` `not in` or == (equal to) or != (not equal to).

# %%
myString = "abcde"
myList = [1,2,3,4]

# %%
# write an if/else statement prints 'Hurrah!' if "abc" is in myString AND 1 is in myList

# %%
# write an if/else statement prints 'Hurrah!' if 1 is in myString or in myList

# %%
# write an if/else statement prints 'Hurrah!' if 1 is in myString is a string AND myList is NOT a string
# hint: remember if type(XXXXX) == str:

# %% [markdown]
# ### For and while
#
# `for` loops can help you iterate over a list of items or elements in a string.

# %%
myList = ["a","b","c"]

# the variable after 'for' does not need to be defined before first mention

for entry in myList:
    print("entry encodes: " + str(entry))
for entry in range(len(myList)):
    print("entry encodes: " + str(entry))

# %% [markdown]
# You can also use `for` loops over interger rangers using the `range` command.

# %%
# here, you are going to run the loop over a range of integers from 0 to 5
for x in range(5):
    print(x)

# %%
for x in range(1,2):
    print(x)

# %% [markdown]
# `while` is also a sort of loop that allows you to enter the loop ONLY if a certain condition is met.  But be careful to not creat an infinite loop where the `while` condition is always met.

# %%
x = 1
while x < 10:
    print(x)
    x += 1 # if we did not alter the x variable the while loop would go on forever!
